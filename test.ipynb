# %%
import torch

# %%
f = torch.tensor([1, 2, 3], dtype=torch.int64)

# %%
print(f)
# Out:
# tensor([1, 2, 3])

# %%
t = torch.nn.Sequential(
    torch.nn.Conv1d(3, 64, 3),
    torch.nn.ReLU(),
)
t.forward(torch.Tensor(1, 3, 10))
# Out:
# tensor([[[0.1481, 0.1481, 0.1481, 0.1481, 0.1481, 0.1481, 0.1481, 0.1481],
#          [0.2467, 0.2467, 0.2467, 0.2467, 0.2467, 0.2467, 0.2467, 0.2467],
#          [0.0434, 0.0434, 0.0434, 0.0434, 0.0434, 0.0434, 0.0434, 0.0434],
#          [0.0328, 0.0328, 0.0328, 0.0328, 0.0328, 0.0328, 0.0328, 0.0328],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.2646, 0.2646, 0.2646, 0.2646, 0.2646, 0.2646, 0.2646, 0.2646],
#          [0.1742, 0.1742, 0.1742, 0.1742, 0.1742, 0.1742, 0.1742, 0.1742],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0113, 0.0113, 0.0113, 0.0113, 0.0113, 0.0113, 0.0113, 0.0113],
# ...
